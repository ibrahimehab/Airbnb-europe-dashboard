# %%
import pandas as pd 
import numpy as np

# %%
original = pd.read_csv("Airbnb_Combined_Data.csv")
scraped = pd.read_csv("airbnb_listings.csv")

print("Original columns:")
print(original.columns.tolist())

print("\nScraped columns:")
print(scraped.columns.tolist())
# Out:
# Original columns:
# ['Unnamed: 0', 'realSum', 'room_type', 'room_shared', 'room_private', 'person_capacity', 'host_is_superhost', 'multi', 'biz', 'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist', 'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index', 'rest_index_norm', 'lng', 'lat', 'city', 'day_type']
#
# Scraped columns:
# ['Name', 'city', 'Price', 'Superhost', 'is_fav', 'Rating', 'Reviews', 'URL']

# %%
import pandas as pd

original = pd.read_csv("Airbnb_Combined_Data.csv")
scraped = pd.read_csv("airbnb_listings.csv")

merged = original.merge(scraped, on="URL", how="left")

merged.to_csv("airbnb_merged.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24428\2516556174.py in ?()
#       2
#       3 original = pd.read_csv("Airbnb_Combined_Data.csv")
#       4 scraped = pd.read_csv("airbnb_listings.csv")
#       5
# ----> 6 merged = original.merge(scraped, on="URL", how="left")
#       7
#       8 merged.to_csv("airbnb_merged.csv", index=False)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...
